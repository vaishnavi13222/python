# %%
#list in python 
#List is an oredered and changeable collection that cna store multiple values 
marks = [80,90,75,85]
print(marks)
# Out:
# [80, 90, 75, 85]

# %%
#accessing elements in a list 
marks = [80,90,75,85]
print(marks[0])
print(marks[1])
print(marks[2])
# Out:
# 80
# 90
# 75

# %%
#change elements in a list 
marks = [80,90,75]
marks[1] = 95
print(marks)
# Out:
# [80, 95, 75]

# %%
#add element in a list 
marks = [80,90,75]
marks.append(85)
print(marks)
# Out:
# [80, 90, 75, 85]

# %%
#add element in a list 
marks = [60,70,20]
marks.append(55)
print(marks)
# Out:
# [60, 70, 20, 55]

# %%
 #remove elements from a list 
marks = [80,90,75]
marks.remove(90)
print(marks)
# Out:
# [80, 75]

# %%
numbers = [10,20,30]
numbers.insert(1,15)
print(numbers)
# Out:
# [10, 15, 20, 30]

# %%
 #bitwise operators
a = 5
b = 3
print(a&b)
print(a|b)
print(a^b)
print(a<<b)
print(a>>b)
# Out:
# 1
# 7
# 6
# 40
# 0

# %%
a = 15
b = 3
print(15>>3)
# Out:
# 1

# %%
a = 7
b = 2
print(7>>2)
# Out:
# 1

# %%
a = 13
b = 1
print(13>>1)
# Out:
# 6

# %%
a = 9
b = 2
print(9>>2)
# Out:
# 2

# %%
a = 15
b = 6
print(15<<6)
# Out:
# 960

# %%
a = 12
b = 4
print(12<<4)
# Out:
# 192

# %%
a = 11
b = 5
print(11<<5)
# Out:
# 352

# %%
a = 14
b = 7
print(14<<7)
# Out:
# 1792

# %%
a = [1,2,3]
b = [4,5,6]
a.extend(b)
print(a)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
numbers = [20,20,30,20]
numbers.remove(20)
print(numbers)
# Out:
# [20, 30, 20]

# %%
numbers = [10,20,30]
numbers.clear()
print(numbers)
# Out:
# []

# %%
#index operators
numbers = [10,20,30,40]
print(numbers.index(30))
# Out:
# 2

# %%
#count operators
numbers = [10,20,20,30,20]
print(numbers.count(20))
# Out:
# 3

# %%
numbers = [40,10,30,20]
numbers.sort()
print(numbers)
# Out:
# [10, 20, 30, 40]

# %%
#reverse operators
numbers = [20,10,40,30]
numbers.sort()
print(numbers)
numbers.sort(reverse=True)
print(numbers)
# Out:
# [10, 20, 30, 40]
# [40, 30, 20, 10]

# %%
numbers = [40,30,20,10]
numbers.sort()
print(numbers)
numbers.sort(reverse=True)
print(numbers)
# Out:
# [10, 20, 30, 40]
# [40, 30, 20, 10]

# %%
#copy operators
a = [1,2,3]
b = a.copy()
print(b)
# Out:
# [1, 2, 3]

# %%
numbers = [10,20,30,40,50]
print(numbers[1:4])
print(numbers[:3])
print(numbers[2:])
print(numbers[::-1])
# Out:
# [20, 30, 40]
# [10, 20, 30]
# [30, 40, 50]
# [50, 40, 30, 20, 10]
